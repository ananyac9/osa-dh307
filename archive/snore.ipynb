# %%
from pyedflib import highlevel
import pyedflib as plib
import numpy as np
import statistics as stats
import matplotlib.pyplot as plt

def read_file_signal(file_path, index):
    f = plib.EdfReader(file_path)
    signal = f.readSignal(index)
    f.close()
    return signal

def signal_labels(file_path):
    f = plib.EdfReader(file_path)
    labels = f.getSignalLabels()
    f.close()
    return labels

def plot_signal(label, signal, title):
    plt.figure(figsize=(20, 10))
    plt.plot(signal)
    plt.title(f"{label} for {title}")
    plt.xlabel("time")
    plt.ylabel("amplitude")
    plt.show()

def combined_signal(file_list, index):
    combined_signals = []
    for file in file_list:
        temp = read_file_signal(file, index)
        combined_signals.append(temp)
    return np.concatenate(combined_signals)

edf_files_severe = [
    "c:\\Users\\anany\\Downloads\\00000066-297469[001].edf",
    "c:\\Users\\anany\\Downloads\\00000066-297469[002].edf",
    "c:\\Users\\anany\\Downloads\\00000066-297469[003].edf",
    "c:\\Users\\anany\\Downloads\\00000066-297469[004].edf",
    "c:\\Users\\anany\\Downloads\\00000066-297469[005].edf",
    "c:\\Users\\anany\\Downloads\\00000066-297469[006].edf",
    "c:\\Users\\anany\\Downloads\\00000066-297469[007].edf"
]

edf_files_normal = [
    "C:\\Users\\anany\\Downloads\\00000064-297469[001].edf",
    "C:\\Users\\anany\\Downloads\\00000064-297469[002].edf",
    "C:\\Users\\anany\\Downloads\\00000064-297469[003].edf",
    "C:\\Users\\anany\\Downloads\\00000064-297469[004].edf",
    "C:\\Users\\anany\\Downloads\\00000064-297469[005].edf",
    "C:\\Users\\anany\\Downloads\\00000064-297469[006].edf",
    "C:\\Users\\anany\\Downloads\\00000064-297469[007].edf",
    "C:\\Users\\anany\\Downloads\\00000064-297469[008].edf",
    "C:\\Users\\anany\\Downloads\\00000064-297469[009].edf"
]

edf_files_moderate = [
    "C:\\Users\\anany\\Downloads\\00000074-297469[001].edf",
    "C:\\Users\\anany\\Downloads\\00000074-297469[002].edf",
    "C:\\Users\\anany\\Downloads\\00000074-297469[003].edf",
    "C:\\Users\\anany\\Downloads\\00000074-297469[004].edf",
    "C:\\Users\\anany\\Downloads\\00000074-297469[005].edf",
    "C:\\Users\\anany\\Downloads\\00000074-297469[006].edf",
    "C:\\Users\\anany\\Downloads\\00000074-297469[007].edf",
    "C:\\Users\\anany\\Downloads\\00000074-297469[008].edf",
    "C:\\Users\\anany\\Downloads\\00000074-297469[009].edf"
]

edf_files_mild = [
    "C:\\Users\\anany\\Downloads\\00000067-297469[001].edf",
    "C:\\Users\\anany\\Downloads\\00000067-297469[002].edf",
    "C:\\Users\\anany\\Downloads\\00000067-297469[003].edf",
    "C:\\Users\\anany\\Downloads\\00000067-297469[004].edf",
    "C:\\Users\\anany\\Downloads\\00000067-297469[005].edf",
    "C:\\Users\\anany\\Downloads\\00000067-297469[006].edf",
    "C:\\Users\\anany\\Downloads\\00000067-297469[007].edf",
    "C:\\Users\\anany\\Downloads\\00000067-297469[008].edf",
    "C:\\Users\\anany\\Downloads\\00000067-297469[009].edf",
    "C:\\Users\\anany\\Downloads\\00000067-297469[010].edf",
    "C:\\Users\\anany\\Downloads\\00000067-297469[011].edf",
]

labels = signal_labels(edf_files_normal[0])
print(labels)
# Out:
# ['EEG F3-A2', 'EEG F4-A1', 'EEG A1-A2', 'EEG C3-A2', 'EEG C4-A1', 'EEG O1-A2', 'EEG O2-A1', 'EOG LOC-A2', 'EOG ROC-A2', 'EMG Chin', 'Leg 1', 'Leg 2', 'ECG I', 'RR', 'ECG II', 'Snore', 'Flow Patient', 'Flow Patient', 'Effort THO', 'Effort ABD', 'SpO2', 'Pleth', 'Body', 'Flow Patient', 'xPAP CPAP', 'xPAP IPAP', 'xPAP EPAP', 'Leak Total', 'PulseRate', 'PressCheck', 'ECG IIHF', 'Technical']

# %%
combined_signals_severe_snore = []
j = 15
print(f"severe for {labels[j]}")
for i in range(7):
    plot_signal(labels[j], read_file_signal(edf_files_severe[i], j), f"severe for hour {i+1}")
combined = combined_signal(edf_files_severe, j)
combined_signals_severe_snore.append(combined_signal(edf_files_severe, j))
mean = combined.mean()
mode = stats.mode(combined)
median = stats.median(combined)
print(f"mean: {mean}, mode: {mode}, median: {median}")
print(combined_signals_severe_snore[0].shape)
plot_signal(labels[j], combined_signals_severe_snore[0], "severe combined")
# Out:
# severe for Snore
# mean: -0.008969371509952898, mode: 0.0015259021896696422, median: -0.007629510948348211
# (12600000,)

# %%
combined_signals_normal_snore = []
j = 15
print(f"normal for {labels[j]}")
for i in range(9):
    plot_signal(labels[j], read_file_signal(edf_files_normal[i], j), f"normal for hour {i+1}")
combined = combined_signal(edf_files_normal, j)
combined_signals_normal_snore.append(combined_signal(edf_files_normal, j))
mean = combined.mean()
mode = stats.mode(combined)
median = stats.median(combined)
print(f"mean: {mean}, mode: {mode}, median: {median}")
print(combined_signals_normal_snore[0].shape)
plot_signal(labels[j], combined_signals_normal_snore[0], "normal combined")
# Out:
# normal for Snore
# mean: -1.0473300058337822, mode: -0.03509575036240177, median: -0.016784924086366063
# (15484000,)

# %%
combined_signals_moderate_snore = []
j = 15
print(f"moderate for {labels[j]}")
for i in range(9):
    plot_signal(labels[j], read_file_signal(edf_files_moderate[i], j), f"moderate for hour {i+1}")
combined = combined_signal(edf_files_moderate, j)
combined_signals_moderate_snore.append(combined_signal(edf_files_moderate, j))
mean = combined.mean()
mode = stats.mode(combined)
median = stats.median(combined)
print(f"mean: {mean}, mode: {mode}, median: {median}")
print(combined_signals_moderate_snore[0].shape)
plot_signal(labels[j], combined_signals_moderate_snore[0], "moderate combined")
# Out:
# moderate for Snore
# mean: -0.008871052933397431, mode: -0.11749446860456245, median: -0.03509575036240177
# (14899000,)

# %%
combined_signals_mild_snore = []
j = 15
print(f"mild for {labels[j]}")
for i in range(11):
    plot_signal(labels[j], read_file_signal(edf_files_mild[i], j), f"mild for hour {i+1}")
combined = combined_signal(edf_files_mild, j)
combined_signals_mild_snore.append(combined_signal(edf_files_mild, j))
mean = combined.mean()
mode = stats.mode(combined)
median = stats.median(combined)
print(f"mean: {mean}, mode: {mode}, median: {median}")
print(combined_signals_mild_snore[0].shape)
plot_signal(labels[j], combined_signals_mild_snore[0], "mild combined")
# Out:
# mild for Snore
# mean: -0.008976057380141112, mode: 0.0015259021896696422, median: -0.007629510948348211
# (18255500,)
